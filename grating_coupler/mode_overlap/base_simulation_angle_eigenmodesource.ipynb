# %%
import math
import os

import matplotlib.pyplot as plt
import numpy as np

import meep as mp

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # forward (0-25度)

# %% [markdown]
# 设置不同角度的光源(0-25度) angle_reslution=0.2，光源的强度从0到25度线性降低，获取远场的强度分布并归一化

# %%
# if True compute flux (Gaussian source), if False compute DFT (Continue source)
compute_flux = True
# size of input and output waveguide
w = 0.5
h = 0.2

# resolution size
grid = 0.02
resolution = 1 / grid

# thickness of PML
dpml = 1

##################### length parameter ################
source_height = 0.5  # 与逆向设计中的meta_grarting区域保持一致
input_wvg_length = 5
output_wvg_length = 5
design_region_x = 15
design_region_y = 0.2
sx = input_wvg_length + design_region_x + output_wvg_length + 2 * dpml

##################### height parameter ################
Substrate_thickness = 0.5
BOX_thickness = 2
TOX_thickness = 0.7
near_field_height = 1
sy = BOX_thickness + TOX_thickness + Substrate_thickness + near_field_height + 2 * dpml

cell = mp.Vector3(sx, sy, 0)

# Material setting
Si = mp.Medium(index=3.45)
SiO2 = mp.Medium(index=1.44)
SiN = mp.Medium(index=1.96)


####################### Sources ##########################
wvl = 0.785
fcen = 1 / wvl
fwidth = 0.2 * fcen

start_angle = 0
stop_angle = 25
sources = []
angle_resolution = 0.1
for ii in range(0, int(stop_angle / angle_resolution) + 1, 1):
    angle = ii * angle_resolution
    rot_angle = angle
    k_point = mp.Vector3(fcen * 1).rotate(mp.Vector3(z=1), np.radians(90 - rot_angle))
    sources.append(
        mp.EigenModeSource(
            src=mp.GaussianSource(fcen, fwidth=fwidth),
            center=mp.Vector3(y=0),
            size=mp.Vector3(x=design_region_x),
            direction=mp.NO_DIRECTION,
            eig_kpoint=k_point,
            eig_band=1,
            eig_parity=mp.ODD_Z,
            eig_match_freq=True,
        )
    )
    # the amplitude of source is e_field, the intensity is square of e_field
    sources[ii].amplitude = np.sqrt(int(stop_angle / angle_resolution) - ii)

# angle = 5
# rot_angle = angle
# k_point = mp.Vector3(fcen * 1).rotate(mp.Vector3(z=1), np.radians(90 - rot_angle))
# sources.append(
#     mp.EigenModeSource(
#         src=mp.GaussianSource(fcen, fwidth=fwidth),
#         center=mp.Vector3(y=0),
#         size=mp.Vector3(x=sx - 2 * dpml),
#         direction=mp.NO_DIRECTION,
#         eig_kpoint=k_point,
#         eig_band=1,
#         eig_parity=mp.ODD_Z,
#         eig_match_freq=True,
#     )
# )
# sources[0].amplitude = 2

# set nomrlized source: amplitude is 1 -> flux is 1
# sources[0].amplitude = 1 / mp.GaussianSource(fcen, fwidth=fwidth).fourier_transform(
#     fcen
# )

####################### Sources ##########################

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell,
    boundary_layers=[mp.PML(dpml)],
    sources=sources,
)

# ############### Monitor ###################
nfreq = 1


near_region = mp.FluxRegion(
    center=mp.Vector3(0, 0.5 * sy - dpml - 0.5 * near_field_height, 0),
    size=mp.Vector3(sx - 2 * dpml, 0),
)

near_field = sim.add_mode_monitor(
    fcen,
    fwidth,
    nfreq,
    near_region,
)

near_dft = sim.add_dft_fields(
    [mp.Ez], fcen, fwidth, nfreq, center=near_region.center, size=near_region.size
)

# near2far_field
n2f_field = sim.add_near2far(
    fcen,
    0,
    nfreq,
    near_region,
)

# geometry plot
sim.plot2D()
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
mpt = mp.Vector3(0, 0.5 * sy - dpml - 0.5 * near_field_height, 0)

f = plt.figure(dpi=100)
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)

sim.run(
    mp.at_every(1, Animate),
    until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mpt, 1e-5),
)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00050807 s
# Working in 2D dimensions.
# Computational cell is 27 x 6.2 x 0 with resolution 50
# time for set_epsilon = 0.410266 s
# -----------
# MPB solved for frequency_1(7.8003e-17,1.27389,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.00222335,1.27388,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.00444669,1.27388,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.00667002,1.27387,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.00889333,1.27385,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0111166,1.27384,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0133399,1.27382,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0155631,1.27379,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0177862,1.27376,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0200093,1.27373,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0222324,1.27369,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0244553,1.27365,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0266782,1.27361,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0289011,1.27356,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0311238,1.27351,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0333464,1.27345,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.035569,1.27339,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0377914,1.27332,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0400137,1.27326,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0422359,1.27318,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.044458,1.27311,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0466799,1.27303,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0489017,1.27295,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0511233,1.27286,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0533448,1.27277,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0555661,1.27267,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0577872,1.27257,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0600082,1.27247,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.062229,1.27236,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0644496,1.27225,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.06667,1.27214,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0688902,1.27202,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0711102,1.2719,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.07333,1.27177,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0755495,1.27164,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0777688,1.27151,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0799879,1.27137,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0822068,1.27123,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0844254,1.27108,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0866437,1.27094,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0888617,1.27078,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0910795,1.27063,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0932971,1.27046,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0955143,1.2703,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0977312,1.27013,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.0999479,1.26996,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.102164,1.26978,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.10438,1.2696,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.106596,1.26942,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(0.108811,1.26923,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.111026,1.26904,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.113241,1.26884,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.115456,1.26864,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.11767,1.26844,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.119883,1.26823,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.122097,1.26802,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.124309,1.26781,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.126522,1.26759,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.128734,1.26736,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.130946,1.26714,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.133157,1.26691,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.135368,1.26667,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.137579,1.26643,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.139789,1.26619,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.141999,1.26595,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.144208,1.2657,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.146417,1.26544,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.148625,1.26519,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.150833,1.26492,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.153041,1.26466,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.155248,1.26439,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.157454,1.26412,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.15966,1.26384,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.161866,1.26356,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.164071,1.26328,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.166275,1.26299,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.168479,1.26269,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.170683,1.2624,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.172886,1.2621,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.175089,1.2618,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.177291,1.26149,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.179492,1.26118,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.181693,1.26086,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.183893,1.26054,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.186093,1.26022,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.188292,1.25989,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.190491,1.25956,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.192689,1.25923,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.194886,1.25889,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.197083,1.25855,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.19928,1.2582,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.201475,1.25785,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.20367,1.2575,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.205865,1.25714,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.208059,1.25678,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.210252,1.25641,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.212444,1.25605,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.214636,1.25567,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.216827,1.2553,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.219018,1.25492,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.221208,1.25453,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.223397,1.25414,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.225586,1.25375,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.227774,1.25336,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.229961,1.25296,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.232147,1.25255,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.234333,1.25215,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.236518,1.25174,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.238702,1.25132,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.240886,1.2509,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.243069,1.25048,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.245251,1.25005,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.247432,1.24962,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.249613,1.24919,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.251793,1.24875,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.253972,1.24831,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.25615,1.24787,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.258328,1.24742,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.260505,1.24696,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.26268,1.24651,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.264856,1.24605,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.26703,1.24558,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.269204,1.24512,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.271376,1.24464,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.273548,1.24417,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.275719,1.24369,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.277889,1.24321,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.280059,1.24272,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.282227,1.24223,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.284395,1.24173,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.286562,1.24124,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.288728,1.24073,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.290893,1.24023,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.293057,1.23972,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.29522,1.2392,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.297383,1.23869,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.299544,1.23817,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(0.301705,1.23764,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.303864,1.23711,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.306023,1.23658,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.308181,1.23605,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.310338,1.23551,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.312493,1.23496,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.314648,1.23441,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.316802,1.23386,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.318955,1.23331,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.321107,1.23275,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.323259,1.23219,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.325409,1.23162,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.327558,1.23105,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.329706,1.23048,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.331853,1.2299,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.333999,1.22932,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.336144,1.22874,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.338288,1.22815,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.340431,1.22755,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.342573,1.22696,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.344714,1.22636,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.346854,1.22576,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.348993,1.22515,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.35113,1.22454,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(0.353267,1.22392,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.355403,1.2233,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.357537,1.22268,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.359671,1.22206,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.361803,1.22143,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.363934,1.22079,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.366064,1.22016,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.368193,1.21952,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.370321,1.21887,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.372448,1.21822,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.374574,1.21757,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.376698,1.21692,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.378821,1.21626,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.380944,1.21559,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.383065,1.21493,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.385185,1.21426,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.387303,1.21358,0) = 1.27389 after 88 iters
# MPB solved for frequency_1(0.389421,1.2129,0) = 1.27389 after 88 iters
# MPB solved for frequency_1(0.391537,1.21222,0) = 1.27389 after 88 iters
# MPB solved for frequency_1(0.393652,1.21154,0) = 1.27389 after 88 iters
# MPB solved for frequency_1(0.395766,1.21085,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.397879,1.21016,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.39999,1.20946,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.402101,1.20876,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.40421,1.20806,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.406318,1.20735,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.408424,1.20664,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.41053,1.20592,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.412634,1.2052,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.414737,1.20448,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(0.416838,1.20376,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(0.418938,1.20303,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(0.421037,1.20229,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(0.423135,1.20156,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(0.425232,1.20082,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(0.427327,1.20007,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(0.429421,1.19933,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.431513,1.19857,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.433605,1.19782,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.435694,1.19706,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.437783,1.1963,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.43987,1.19553,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.441956,1.19476,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.444041,1.19399,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.446124,1.19321,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.448206,1.19243,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.450286,1.19165,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.452366,1.19086,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.454443,1.19007,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.45652,1.18927,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.458595,1.18848,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.460668,1.18767,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.46274,1.18687,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.464811,1.18606,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.466881,1.18525,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.468948,1.18443,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(0.471015,1.18361,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.47308,1.18278,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.475144,1.18196,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.477206,1.18113,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.479267,1.18029,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.481326,1.17945,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.483384,1.17861,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.48544,1.17777,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.487495,1.17692,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.489548,1.17606,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.4916,1.17521,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.49365,1.17435,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.495699,1.17348,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.497747,1.17262,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.499793,1.17175,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.501837,1.17087,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.50388,1.17,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.505921,1.16911,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.507961,1.16823,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.509999,1.16734,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.512035,1.16645,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(0.51407,1.16555,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.516104,1.16465,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.518136,1.16375,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.520166,1.16285,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.522195,1.16194,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.524222,1.16102,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.526248,1.16011,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.528272,1.15919,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.530294,1.15826,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.532315,1.15734,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(0.534334,1.1564,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.536351,1.15547,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(0.538367,1.15453,0) = 1.27389 after 82 iters
# on time step 1629 (time=16.29), 0.00245621 s/step
# on time step 3318 (time=33.18), 0.00236901 s/step
# field decay(t = 50.01): 1754806.5399019115 / 1754806.5399019115 = 1.0
# on time step 5027 (time=50.27), 0.00234112 s/step
# on time step 6758 (time=67.58), 0.00231146 s/step
# on time step 8493 (time=84.93), 0.00230629 s/step
# field decay(t = 100.01): 1.5683878263624537e-08 / 1754806.5399019115 = 8.937668003278138e-15
# Normalizing field data...
# run 0 finished at t = 100.01 (10001 timesteps)

# %%
filename = "base_simulation_angle_source.mp4"
Animate.to_mp4(10, filename)

from IPython.core.display import Video
Video(filename)
# Out:
# Generating MP4...
# <video src="base_simulation_angle_source.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# **DFT field**

# %%
output_dft = sim.get_dft_array(near_dft, mp.Ez, 0)
[x, y, z, w] = sim.get_array_metadata(dft_cell=near_dft) # type: ignore

# %%
figure, ax = plt.subplots()
total_power = np.sum(np.abs(output_dft) ** 2 * (x[1] - x[0]))
print(total_power)
norm_output_dft = output_dft / np.sqrt(total_power)
plt.plot(x, np.real(norm_output_dft), "-b")
plt.plot(x, np.imag(norm_output_dft), "--r")
plt.plot(x, np.abs(norm_output_dft), "-r", linewidth=3)
plt.title(r"$ E_z $ of near field at 785nm wavelength")
ax.set_xlabel("x")
ax.set_ylabel(r"$ E_z $")
np.save('near_field.npy', norm_output_dft)
# Out:
# 14518433.496843293

# %%
print(np.abs(np.sum(norm_output_dft * np.conj(norm_output_dft))))
# Out:
# 50.000000000001066

# %%
10800/60/60
# Out:
# 3.0

# %%
print(np.sum(np.abs(norm_output_dft)**2*(x[1]-x[0])))
# Out:
# 1.0

# %%
# dft ot near field
kx = np.fft.fftshift(np.fft.fftfreq(len(x), grid))
near_field_fft = np.fft.fftshift(np.fft.fft(output_dft))

k = 1 / wvl
kx[np.abs(kx) > k] = np.nan
angle = np.arcsin(kx / k) * 180 / np.pi

figure, ax = plt.subplots()
plt.plot(angle, np.abs(near_field_fft) ** 2, "-o")
# plt.scatter(angle, near_field_fft)
plt.title(r"$ Ez $ of DFT")
ax.set_xlabel("angle")
ax.set_ylabel(r"$ E_z $")
ax.set_xlim(-90, 90)

max_index = np.argmax(np.abs(near_field_fft) ** 2)
print(f"The angle of maximum intensity is {angle[max_index]}")
# Out:
# The angle of maximum intensity is 3.5947850319926697

# %% [markdown]
# source.amplitude is 1, flux is 15.4

# %%
am = 1 / mp.GaussianSource(fcen, fwidth=fwidth).fourier_transform(fcen)
print(np.abs(am))
print((1 / np.abs(am)) ** 2)
# Out:
# 0.25477707006369427
# 15.405624999999999

# %% [markdown]
# **far field**

# %%
# anzhao1dianshu1
ff_distance = 1e6  # far-field distance from near-field monitor
ff_angle = 30  # far-field cone angle
ff_npts = 1000  # number of far-field points
# single-side far-field length
ff_length = ff_distance * math.tan(math.radians(ff_angle))  # far-field length
# [-ff_length, ff_length]
ff_lengths = np.linspace(-ff_length, ff_length, ff_npts)  # far-field lengths
# resolution
ff_res = ff_npts / (2 * ff_length)  # far-field length resolution

ff = sim.get_farfields(
    n2f_field,
    ff_res,
    center=mp.Vector3(0, ff_distance),
    size=mp.Vector3(x=2 * ff_length),
)
# [-angle, angle]
angles = [math.degrees(math.atan(f)) for f in ff_lengths / ff_distance]
rel_enh = np.abs(ff["Ez"])**2

figure, ax = plt.subplots(figsize=(10, 10))
plt.plot(angles, rel_enh, "-o")
plt.title(r"$ {|E_z|}^2 $ far field")
ax.set_xlabel(r"angle $ \theta $")
ax.set_ylabel(r"$ {|E_z|}^2 $")
ax.set_xticks(range(-30, 35, 5))
index = np.argmax(rel_enh)
print(f"Output_angle of grating coupler: {angles[index]} degree")
print(f"max of far field: {np.max(rel_enh)}")
# Out:
# Output_angle of grating coupler: 2.7462612353703206 degree
# max of far field: 71.22926681114434

# %% [markdown]
# 计算总场power

# %%
total_power = mp.get_fluxes(near_field)
print(total_power)
# Out:
# [14407006.266743079]

# %%
# 验证在0-25度光源传播下，monitor的远场角度分布
# 设置角度的分辨率为 0.5degree
d_angle = 0.2
ff_distance = 1e6
ff_angle = 89
ff_number = int(2 / d_angle) * ff_angle + 1
ff_angles = np.linspace(-ff_angle, ff_angle, ff_number)
ff_points = [
    mp.Vector3(fx, 1e6, 0) for fx in np.tan(np.radians(ff_angles)) * ff_distance
]

ob_list = [sim.get_farfield(n2f_field, ff_point) for ff_point in ff_points]
n2f_angle_Ez = [Ez[2] for Ez in ob_list]
rel_enh = np.abs(n2f_angle_Ez) ** 2
figure, ax = plt.subplots(figsize=(10, 10))
plt.plot(ff_angles, rel_enh, "-o")
plt.title(r"$ {|Ez|}^2 $ far field")
ax.set_xlabel(r"angle $ \theta$")
ax.set_ylabel(r"$ {|E_z|}^2 $")
# Out:
# Text(0, 0.5, '$ {|E_z|}^2 $')

# %% [markdown]
# **验证far field计算得到的power与mp.get_fluxes()相等**

# %%
d_length = []
for angle in ff_angles:
    # The length of each angle in the far field
    length = ff_distance / np.cos(np.radians(angle))
    d_length.append(np.radians(d_angle) * length)

print(f"The total length {np.sum(d_length)} um calculated by angles")

energy = 0
for ii in range(0, ff_number, 1):
    energy = energy + d_length[ii] * (np.abs(n2f_angle_Ez[ii]) ** 2)
print(f"The power of near_field is {energy}")

near_field_flux = mp.get_fluxes(near_field)
print(f"The power of near_field is {near_field_flux[0]}")
# Out:
# The total length 9689347.824509013 um calculated by angles
# The power of near_field is 14454828.266134597
# The power of near_field is 14407006.266743079

# %% [markdown]
# **Normalized power: 1**

# %%
norm_rel = rel_enh / energy
figure, ax = plt.subplots(figsize=(10, 8))
plt.plot(ff_angles, norm_rel, "-o")
plt.title(r"Norm. $ {|Ez|}^2 $ far field")
ax.set_xlabel(r"angle $ \theta$")
ax.set_ylabel(r"Norm. $ {|E_z|}^2 $")
np.save("norm_rel_1.npy", norm_rel)
print(norm_rel.shape)
# Out:
# (891,)

# %% [markdown]
# **验证归一化之后的enegy is 1**

# %%
norm_energy = 0
for ii in range(0, ff_number, 1):
    norm_energy = norm_energy + d_length[ii] * (norm_rel[ii])
print(f"The power of near_field is {norm_energy}")
# Out:
# The power of near_field is 1.0

# %%
# norm_rel_load = np.load('norm_rel.npy')
# figure= plt.figure(figsize=(10, 10))
# plt.plot(ff_angles, norm_rel_load, "-o")

# %% [markdown]
# # forward (-25-0度)

# %% [markdown]
# 当光栅周期较小时，会出现光栅的矢量大于波导的传播常数，会使得出射光束在负方向，因此考虑到最下化grating coupler的尺寸，尝试在负方向 (**-25-0度**) 远场分布

# %%
# if True compute flux (Gaussian source), if False compute DFT (Continue source)
compute_flux = True
# size of input and output waveguide
w = 0.5
h = 0.2

# resolution size
grid = 0.02
resolution = 1 / grid

# thickness of PML
dpml = 1

##################### length parameter ################
source_height = 0.5  # 与逆向设计中的meta_grarting区域保持一致
input_wvg_length = 5
output_wvg_length = 5
design_region_x = 15
design_region_y = 0.2
sx = input_wvg_length + design_region_x + output_wvg_length + 2 * dpml

##################### height parameter ################
Substrate_thickness = 0.5
BOX_thickness = 2
TOX_thickness = 0.7
near_field_height = 1
sy = BOX_thickness + TOX_thickness + Substrate_thickness + near_field_height + 2 * dpml

cell = mp.Vector3(sx, sy, 0)

# Material setting
Si = mp.Medium(index=3.45)
SiO2 = mp.Medium(index=1.44)
SiN = mp.Medium(index=1.96)


####################### Sources ##########################
wvl = 0.785
fcen = 1 / wvl
fwidth = 0.2 * fcen

start_angle = 0
stop_angle = 25
sources = []
angle_resolution = 0.1
for ii in range(0, int(stop_angle / angle_resolution) + 1, 1):
    angle = ii * angle_resolution
    rot_angle = angle
    # 修改 k_point 角度从(0, 25) -> (0, -25)
    k_point = mp.Vector3(fcen * 1).rotate(mp.Vector3(z=1), np.radians(90 + rot_angle))
    sources.append(
        mp.EigenModeSource(
            src=mp.GaussianSource(fcen, fwidth=fwidth),
            center=mp.Vector3(y=0),
            size=mp.Vector3(x=design_region_x),
            direction=mp.NO_DIRECTION,
            eig_kpoint=k_point,
            eig_band=1,
            eig_parity=mp.ODD_Z,
            eig_match_freq=True,
        )
    )
    # the amplitude of source is e_field, the intensity is square of e_field
    sources[ii].amplitude = np.sqrt(int(stop_angle / angle_resolution) - ii)

# angle = 5
# rot_angle = angle
# k_point = mp.Vector3(fcen * 1).rotate(mp.Vector3(z=1), np.radians(90 - rot_angle))
# sources.append(
#     mp.EigenModeSource(
#         src=mp.GaussianSource(fcen, fwidth=fwidth),
#         center=mp.Vector3(y=0),
#         size=mp.Vector3(x=sx - 2 * dpml),
#         direction=mp.NO_DIRECTION,
#         eig_kpoint=k_point,
#         eig_band=1,
#         eig_parity=mp.ODD_Z,
#         eig_match_freq=True,
#     )
# )
# sources[0].amplitude = 2

# set nomrlized source: amplitude is 1 -> flux is 1
# sources[0].amplitude = 1 / mp.GaussianSource(fcen, fwidth=fwidth).fourier_transform(
#     fcen
# )

####################### Sources ##########################

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell,
    boundary_layers=[mp.PML(dpml)],
    sources=sources,
)

# ############### Monitor ###################
nfreq = 1


near_region = mp.FluxRegion(
    center=mp.Vector3(0, 0.5 * sy - dpml - 0.5 * near_field_height, 0),
    size=mp.Vector3(sx - 2 * dpml, 0),
)

near_field = sim.add_mode_monitor(
    fcen,
    fwidth,
    nfreq,
    near_region,
)

near_dft = sim.add_dft_fields(
    [mp.Ez], fcen, fwidth, nfreq, center=near_region.center, size=near_region.size
)

# near2far_field
n2f_field = sim.add_near2far(
    fcen,
    0,
    nfreq,
    near_region,
)

# geometry plot
sim.plot2D()
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
mpt = mp.Vector3(0, 0.5 * sy - dpml - 0.5 * near_field_height, 0)

f = plt.figure(dpi=100)
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)

sim.run(
    mp.at_every(1, Animate),
    until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mpt, 1e-5),
)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000440836 s
# Working in 2D dimensions.
# Computational cell is 27 x 6.2 x 0 with resolution 50
# time for set_epsilon = 0.417541 s
# -----------
# MPB solved for frequency_1(7.8003e-17,1.27389,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.00222335,1.27388,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.00444669,1.27388,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.00667002,1.27387,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.00889333,1.27385,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0111166,1.27384,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0133399,1.27382,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0155631,1.27379,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0177862,1.27376,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0200093,1.27373,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0222324,1.27369,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0244553,1.27365,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0266782,1.27361,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0289011,1.27356,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0311238,1.27351,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0333464,1.27345,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.035569,1.27339,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0377914,1.27332,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0400137,1.27326,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0422359,1.27318,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.044458,1.27311,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0466799,1.27303,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0489017,1.27295,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0511233,1.27286,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0533448,1.27277,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0555661,1.27267,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0577872,1.27257,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0600082,1.27247,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.062229,1.27236,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0644496,1.27225,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.06667,1.27214,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0688902,1.27202,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0711102,1.2719,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.07333,1.27177,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0755495,1.27164,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0777688,1.27151,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0799879,1.27137,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0822068,1.27123,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0844254,1.27108,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0866437,1.27094,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0888617,1.27078,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0910795,1.27063,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0932971,1.27046,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0955143,1.2703,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0977312,1.27013,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.0999479,1.26996,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.102164,1.26978,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.10438,1.2696,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.106596,1.26942,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.108811,1.26923,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.111026,1.26904,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.113241,1.26884,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.115456,1.26864,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.11767,1.26844,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.119883,1.26823,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.122097,1.26802,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.124309,1.26781,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.126522,1.26759,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.128734,1.26736,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.130946,1.26714,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.133157,1.26691,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.135368,1.26667,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.137579,1.26643,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.139789,1.26619,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.141999,1.26595,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.144208,1.2657,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.146417,1.26544,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.148625,1.26519,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.150833,1.26492,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.153041,1.26466,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.155248,1.26439,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.157454,1.26412,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.15966,1.26384,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.161866,1.26356,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.164071,1.26328,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.166275,1.26299,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.168479,1.26269,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.170683,1.2624,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.172886,1.2621,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.175089,1.2618,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.177291,1.26149,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.179492,1.26118,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.181693,1.26086,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.183893,1.26054,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.186093,1.26022,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.188292,1.25989,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.190491,1.25956,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.192689,1.25923,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.194886,1.25889,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.197083,1.25855,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.19928,1.2582,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.201475,1.25785,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.20367,1.2575,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.205865,1.25714,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.208059,1.25678,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.210252,1.25641,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.212444,1.25605,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.214636,1.25567,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.216827,1.2553,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.219018,1.25492,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.221208,1.25453,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.223397,1.25414,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.225586,1.25375,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.227774,1.25336,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.229961,1.25296,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.232147,1.25255,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.234333,1.25215,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.236518,1.25174,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.238702,1.25132,0) = 1.27389 after 97 iters
# MPB solved for frequency_1(-0.240886,1.2509,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.243069,1.25048,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.245251,1.25005,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.247432,1.24962,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.249613,1.24919,0) = 1.27389 after 93 iters
# MPB solved for frequency_1(-0.251793,1.24875,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.253972,1.24831,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.25615,1.24787,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.258328,1.24742,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.260505,1.24696,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.26268,1.24651,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.264856,1.24605,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.26703,1.24558,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.269204,1.24512,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.271376,1.24464,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.273548,1.24417,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.275719,1.24369,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.277889,1.24321,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.280059,1.24272,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.282227,1.24223,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.284395,1.24173,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.286562,1.24124,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.288728,1.24073,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.290893,1.24023,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.293057,1.23972,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.29522,1.2392,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.297383,1.23869,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.299544,1.23817,0) = 1.27389 after 96 iters
# MPB solved for frequency_1(-0.301705,1.23764,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.303864,1.23711,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.306023,1.23658,0) = 1.27389 after 91 iters
# MPB solved for frequency_1(-0.308181,1.23605,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.310338,1.23551,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.312493,1.23496,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.314648,1.23441,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.316802,1.23386,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.318955,1.23331,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.321107,1.23275,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.323259,1.23219,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.325409,1.23162,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.327558,1.23105,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.329706,1.23048,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.331853,1.2299,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.333999,1.22932,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.336144,1.22874,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.338288,1.22815,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.340431,1.22755,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.342573,1.22696,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.344714,1.22636,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.346854,1.22576,0) = 1.27389 after 95 iters
# MPB solved for frequency_1(-0.348993,1.22515,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.35113,1.22454,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.353267,1.22392,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.355403,1.2233,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.357537,1.22268,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.359671,1.22206,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.361803,1.22143,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.363934,1.22079,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.366064,1.22016,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.368193,1.21952,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.370321,1.21887,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.372448,1.21822,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.374574,1.21757,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.376698,1.21692,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.378821,1.21626,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.380944,1.21559,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.383065,1.21493,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.385185,1.21426,0) = 1.27389 after 94 iters
# MPB solved for frequency_1(-0.387303,1.21358,0) = 1.27389 after 88 iters
# MPB solved for frequency_1(-0.389421,1.2129,0) = 1.27389 after 88 iters
# MPB solved for frequency_1(-0.391537,1.21222,0) = 1.27389 after 88 iters
# MPB solved for frequency_1(-0.393652,1.21154,0) = 1.27389 after 88 iters
# MPB solved for frequency_1(-0.395766,1.21085,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.397879,1.21016,0) = 1.27389 after 92 iters
# MPB solved for frequency_1(-0.39999,1.20946,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.402101,1.20876,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.40421,1.20806,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.406318,1.20735,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.408424,1.20664,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.41053,1.20592,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.412634,1.2052,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.414737,1.20448,0) = 1.27389 after 87 iters
# MPB solved for frequency_1(-0.416838,1.20376,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(-0.418938,1.20303,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(-0.421037,1.20229,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(-0.423135,1.20156,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(-0.425232,1.20082,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(-0.427327,1.20007,0) = 1.27389 after 86 iters
# MPB solved for frequency_1(-0.429421,1.19933,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.431513,1.19857,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.433605,1.19782,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.435694,1.19706,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.437783,1.1963,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.43987,1.19553,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.441956,1.19476,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.444041,1.19399,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.446124,1.19321,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.448206,1.19243,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.450286,1.19165,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.452366,1.19086,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.454443,1.19007,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.45652,1.18927,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.458595,1.18848,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.460668,1.18767,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.46274,1.18687,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.464811,1.18606,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.466881,1.18525,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.468948,1.18443,0) = 1.27389 after 84 iters
# MPB solved for frequency_1(-0.471015,1.18361,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.47308,1.18278,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.475144,1.18196,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.477206,1.18113,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.479267,1.18029,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.481326,1.17945,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.483384,1.17861,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.48544,1.17777,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.487495,1.17692,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.489548,1.17606,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.4916,1.17521,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.49365,1.17435,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.495699,1.17348,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.497747,1.17262,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.499793,1.17175,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.501837,1.17087,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.50388,1.17,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.505921,1.16911,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.507961,1.16823,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.509999,1.16734,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.512035,1.16645,0) = 1.27389 after 83 iters
# MPB solved for frequency_1(-0.51407,1.16555,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.516104,1.16465,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.518136,1.16375,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.520166,1.16285,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.522195,1.16194,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.524222,1.16102,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.526248,1.16011,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.528272,1.15919,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.530294,1.15826,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.532315,1.15734,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.534334,1.1564,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.536351,1.15547,0) = 1.27389 after 82 iters
# MPB solved for frequency_1(-0.538367,1.15453,0) = 1.27389 after 95 iters
# on time step 1651 (time=16.51), 0.00242338 s/step
# on time step 3412 (time=34.12), 0.0022715 s/step
# field decay(t = 50.01): 1754806.3517365744 / 1754806.3517365744 = 1.0
# on time step 5174 (time=51.74), 0.00227042 s/step
# on time step 6938 (time=69.38), 0.00226765 s/step
# on time step 8700 (time=87), 0.00227763 s/step
# field decay(t = 100.01): 1.568398377353313e-08 / 1754806.3517365744 = 8.93772908789172e-15
# Normalizing field data...
# run 0 finished at t = 100.01 (10001 timesteps)

# %%
filename = "base_simulation_angle_source.mp4"
Animate.to_mp4(10, filename)

from IPython.core.display import Video

Video(filename)
# Out:
# Generating MP4...
# <video src="base_simulation_angle_source.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
output_dft = sim.get_dft_array(near_dft, mp.Ez, 0)
[x, y, z, w] = sim.get_array_metadata(dft_cell=near_dft)  # type: ignore
figure, ax = plt.subplots()
total_power = np.sum(np.abs(output_dft) ** 2 * (x[1] - x[0]))
print(total_power)
norm_output_dft = output_dft / np.sqrt(total_power)
plt.plot(x, np.real(norm_output_dft), "-b")
plt.plot(x, np.imag(norm_output_dft), "--r")
plt.plot(x, np.abs(norm_output_dft), "-r", linewidth=3)
plt.title(r"$ E_z $ of near field at 785nm wavelength (-25-0)")
ax.set_xlabel("x")
ax.set_ylabel(r"$ E_z $")
np.save("near_field.npy", norm_output_dft)
# Out:
# 14518333.69123378

# %%
print(np.abs(np.sum(norm_output_dft * np.conj(norm_output_dft))))
# Out:
# 50.00000000000107

# %%
ff_distance = 1e6  # far-field distance from near-field monitor
ff_angle = 30  # far-field cone angle
ff_npts = 1000  # number of far-field points
# single-side far-field length
ff_length = ff_distance * math.tan(math.radians(ff_angle))  # far-field length
# [-ff_length, ff_length]
ff_lengths = np.linspace(-ff_length, ff_length, ff_npts)  # far-field lengths
# resolution
ff_res = ff_npts / (2 * ff_length)  # far-field length resolution

ff = sim.get_farfields(
    n2f_field,
    ff_res,
    center=mp.Vector3(0, ff_distance),
    size=mp.Vector3(x=2 * ff_length),
)
# [-angle, angle]
angles = [math.degrees(math.atan(f)) for f in ff_lengths / ff_distance]
rel_enh = np.abs(ff["Ez"])

figure, ax = plt.subplots(figsize=(10, 10))
plt.plot(angles, rel_enh, "-o")
plt.title(r"$ {|E_z|}^2 $ far field")
ax.set_xlabel(r"angle $ \theta $")
ax.set_ylabel(r"$ {|E_z|}^2 $")
ax.set_xticks(range(-30, 35, 5))
index = np.argmax(rel_enh)
print(f"Output_angle of grating coupler: {angles[index]} degree")
print(f"max of far field: {np.max(rel_enh)}")
# Out:
# Output_angle of grating coupler: -2.7462612353703135 degree
# max of far field: 71.22925455924845
